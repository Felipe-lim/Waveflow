# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt
from pydub import AudioSegment

# %%
def cria_chroma_from_sample(sample, sample_rate):

    y_harmonic = librosa.effects.harmonic(sample)

    # Compute chroma features from the harmonic signal
    # Transforma cada faixa de frequencia em notas musicais
    chromagram = librosa.feature.chroma_cqt(y=y_harmonic,
                                            sr=sample_rate)
    
    return chromagram

# %%
def identifica_fundamental(chroma):

    #critério de seleção: linha com o maior valor
    linhas_somadas = np.sum(chroma, axis=1)

    indice_nota = np.argmax(linhas_somadas) 

    notas_musicais = {
    0: "Dó",
    1: "Dó#",
    2: "Ré",
    3: "Ré#",
    4: "Mi",
    5: "Fá",
    6: "Fá#",
    7: "Sol",
    8: "Sol#",
    9: "Lá",
    10: "Lá#",
    11: "Si"
    }

    nota_fundamental = notas_musicais[indice_nota]
    return nota_fundamental

# %%
def contar_sequencias_notas(lista):
    # recebe uma sequencia de notas e transforma em uma matriz 2x2 com a nota e a quantidade de tempos que ela se repetiu
    
    contagens_sequenciais = []
    atual = lista[0]
    contagem = 0

    for elemento in lista:
        if elemento == atual:
            contagem += 1
        else:
            contagens_sequenciais.append([atual, contagem])
            atual = elemento
            contagem = 1
    contagens_sequenciais.append([atual, contagem])  # Para o último elemento

    # Sua lista de entrada
    #entrada = [1, 1, 1, 2, 2, 3, 3, 3, 3, 1, 1, 1, 1, 2, 2]
    #saida   = [[1, 3], [2, 2], [3, 4], [1, 4], [2, 2]]

    # Chamar a função para contar sequências
    #resultado = contar_sequencias_notas(entrada)

    return contagens_sequenciais

# %%
def final_process(file = str):
    # Carregar o arquivo mp3
    audio = AudioSegment.from_file(file, format="mp3")

    # Definindo a duração de cada segmento em milissegundos
    #duracao_segmento = 167  # 1/6 segundos
    duracao_segmento = 500  # 1/6 segundos

    notas_fundamentais_acordes = []

    # Segmentando o áudio
    for i in range(0, len(audio), duracao_segmento):
        segmento = audio[i:i + duracao_segmento]
        print(i, i+duracao_segmento)

        sample = np.array(segmento.get_array_of_samples()).astype(np.float32) / 32768
        sample_rate = segmento.frame_rate

        chromagram = cria_chroma_from_sample(sample=sample, sample_rate=sample_rate)

        fundamental = identifica_fundamental(chroma=chromagram)

        notas_fundamentais_acordes.append(fundamental)

    
    notas_fundamentais_acordes = contar_sequencias_notas(notas_fundamentais_acordes)
    return(notas_fundamentais_acordes)

# %%
notas_final = final_process('original.mp3')
# Out:
# 0 500
# 500 1000
# c:\Users\felip\AppData\Local\Programs\Python\Python312\Lib\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=750
#   warnings.warn(
# c:\Users\felip\AppData\Local\Programs\Python\Python312\Lib\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=375
#   warnings.warn(
# 1000 1500
# 1500 2000
# 2000 2500
# 2500 3000
# 3000 3500
# 3500 4000
# 4000 4500
# 4500 5000
# 5000 5500
# 5500 6000
# 6000 6500
# 6500 7000
# 7000 7500
# 7500 8000
# 8000 8500
# 8500 9000
# 9000 9500
# 9500 10000
# 10000 10500
# 10500 11000
# 11000 11500
# 11500 12000
# 12000 12500
# 12500 13000
# 13000 13500
# 13500 14000
# 14000 14500
# 14500 15000
# 15000 15500
# 15500 16000
# 16000 16500
# 16500 17000
# 17000 17500
# 17500 18000
# 18000 18500
# 18500 19000
# 19000 19500
# 19500 20000
# 20000 20500
# 20500 21000
# 21000 21500
# 21500 22000
# 22000 22500
# 22500 23000
# 23000 23500
# 23500 24000
# 421500 422000
# 422000 422500
# 422500 423000
# 423000 423500
# 423500 424000
# 424000 424500
# 424500 425000
# 425000 425500
# 425500 426000
# 426000 426500
# 426500 427000
# 427000 427500
# 427500 428000
# 428000 428500
# 428500 429000
# 429000 429500
# 429500 430000
# 430000 430500
# 430500 431000
# 431000 431500
# 431500 432000
# 432000 432500
# 432500 433000
# 433000 433500
# 433500 434000
# 434000 434500
# 434500 435000
# 435000 435500
# 435500 436000
# 436000 436500
# 436500 437000
# 437000 437500
# 437500 438000
# 438000 438500
# 438500 439000
# 439000 439500
# 439500 440000
# 440000 440500
# 440500 441000
# 441000 441500
# 441500 442000
# 442000 442500
# 442500 443000
# 443000 443500
# 443500 444000
# 444000 444500
# 444500 445000
# 445000 445500
# 445500 446000
# 446000 446500
# 446500 447000
# 447000 447500
# 447500 448000
# 448000 448500
# 448500 449000
# 449000 449500
# 449500 450000
# 450000 450500
# 450500 451000
# 451000 451500
# 451500 452000
# 452000 452500
# 452500 453000
# 453000 453500
# 453500 454000
# 454000 454500
# 454500 455000
# 455000 455500
# 455500 456000
# 456000 456500
# 456500 457000
# 457000 457500
# 457500 458000
# 458000 458500
# 458500 459000
# 459000 459500
# 459500 460000
# 460000 460500
# 460500 461000
# 461000 461500
# 461500 462000
# 462000 462500
# 462500 463000
# 463000 463500
# 463500 464000
# 464000 464500
# 464500 465000
# 465000 465500
# 465500 466000
# 466000 466500
# 466500 467000
# 467000 467500
# 467500 468000
# 468000 468500
# 468500 469000
# 469000 469500
# 469500 470000
# 470000 470500
# 470500 471000
# 471000 471500
# c:\Users\felip\AppData\Local\Programs\Python\Python312\Lib\site-packages\librosa\core\pitch.py:101: UserWarning: Trying to estimate tuning from empty frequency set.
#   return pitch_tuning(
# c:\Users\felip\AppData\Local\Programs\Python\Python312\Lib\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=960
#   warnings.warn(
# c:\Users\felip\AppData\Local\Programs\Python\Python312\Lib\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=480
#   warnings.warn(
# c:\Users\felip\AppData\Local\Programs\Python\Python312\Lib\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=240
#   warnings.warn(
# c:\Users\felip\AppData\Local\Programs\Python\Python312\Lib\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=120
#   warnings.warn(
# c:\Users\felip\AppData\Local\Programs\Python\Python312\Lib\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=60
#   warnings.warn(
# c:\Users\felip\AppData\Local\Programs\Python\Python312\Lib\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=30
#   warnings.warn(

# %% [markdown]
# as notas estão indo entre 7 e 7 unidades de tempo escolhidas. Com variação de + - 1

# %% [markdown]
# As quintas aparecem durante a transicao de acordes, pois imagine que durante o tempo
# analisado, metade do array estava em la, metade estava em sol, nesse caso, talvez
# a quinta do primeiro acorde fique evidente por estar soando o tempo todo

# %%
notas_final
# Out:
# [['Dó#', 7],
#  ['Dó', 7],
#  ['Sol', 2],
#  ['Ré', 1],
#  ['Sol', 3],
#  ['Ré', 1],
#  ['Lá', 2],
#  ['Mi', 1],
#  ['Lá', 1],
#  ['Mi', 1],
#  ['Lá', 1],
#  ['Mi', 1],
#  ['Fá', 6],
#  ['Dó', 7],
#  ['Ré', 1],
#  ['Sol', 1],
#  ['Ré', 2],
#  ['Sol', 3],
#  ['Ré', 1],
#  ['Lá', 2],
#  ['Mi', 1],
#  ['Lá', 2],
#  ['Mi', 1],
#  ['Fá', 2],
#  ['Dó', 2],
#  ['Fá', 3],
#  ['Dó', 7],
#  ['Sol', 7],
#  ['Lá', 6],
#  ['Mi', 1],
#  ['Fá', 2],
#  ['Dó', 1],
#  ['Fá', 3],
#  ['Dó', 7],
#  ['Sol', 6],
#  ['Ré', 1],
#  ['Lá', 4],
#  ['Mi', 1],
#  ['Lá', 1],
#  ['Mi', 1],
#  ['Fá', 7],
#  ['Dó', 7],
#  ['Sol', 6],
#  ['Ré', 1],
#  ['Lá', 2],
#  ['Mi', 2],
#  ['Lá', 2],
#  ['Mi', 1],
#  ['Fá', 6],
#  ['Dó', 7],
#  ['Sol', 7],
#  ['Lá', 7],
#  ['Fá', 6],
#  ['Dó#', 1],
#  ['Dó', 7],
#  ['Sol', 2],
#  ['Ré', 1],
#  ['Sol', 3],
#  ['Ré', 1],
#  ['Lá', 2],
#  ['Mi', 2],
#  ['Lá', 2],
#  ['Fá', 3],
#  ['Dó', 1],
#  ['Fá', 3],
#  ['Dó', 7],
#  ['Sol', 2],
#  ['Ré', 1],
#  ['Sol', 3],
#  ['Ré', 1],
#  ['Lá', 2],
#  ['Mi', 3],
#  ['Lá', 1],
#  ['Mi', 1],
#  ['Fá', 6],
#  ['Dó', 7],
#  ['Ré', 1],
#  ['Sol', 1],
#  ['Ré', 2],
#  ['Sol', 3],
#  ['Lá', 3],
#  ['Mi', 1],
#  ['Lá', 3],
#  ['Fá', 3],
#  ['Dó', 1],
#  ['Fá', 3],
#  ['Dó', 7],
#  ['Sol', 2],
#  ['Ré', 1],
#  ['Sol', 4],
#  ['Lá', 2],
#  ['Mi', 1],
#  ['Lá', 1],
#  ['Mi', 3],
#  ['Fá', 2],
#  ['Dó', 1],
#  ['Fá', 3],
#  ['Dó', 7],
#  ['Sol', 7],
#  ['Lá', 4],
#  ['Mi', 1],
#  ['Lá', 1],
#  ['Mi', 1],
#  ['Fá', 7],
#  ['Dó', 7],
#  ['Sol', 6],
#  ['Ré', 1],
#  ['Lá', 3],
#  ['Mi', 1],
#  ['Lá', 1],
#  ['Mi', 2],
#  ['Fá', 6],
#  ['Dó', 7],
#  ['Sol', 7],
#  ['Lá', 4],
#  ['Mi', 1],
#  ['Lá', 1],
#  ['Mi', 1],
#  ['Fá', 7],
#  ['Dó', 7],
#  ['Sol', 5],
#  ['Ré', 2],
#  ['Lá', 3],
#  ['Mi', 1],
#  ['Lá', 2],
#  ['Fá', 6],
#  ['Lá', 1],
#  ['Dó', 7],
#  ['Sol', 2],
#  ['Ré', 1],
#  ['Sol', 2],
#  ['Ré', 2],
#  ['Lá', 1],
#  ['Mi', 4],
#  ['Lá', 1],
#  ['Mi', 1],
#  ['Fá', 6],
#  ['Dó', 7],
#  ['Ré', 1],
#  ['Sol', 1],
#  ['Ré', 1],
#  ['Sol', 3],
#  ['Ré', 1],
#  ['Lá', 2],
#  ['Mi', 3],
#  ['Lá', 1],
#  ['Mi', 1],
#  ['Fá', 7],
#  ['Dó', 7],
#  ['Sol', 7],
#  ['Lá', 1],
#  ['Mi', 6],
#  ['Fá', 2],
#  ['Dó', 1],
#  ['Fá', 3],
#  ['Dó', 7],
#  ['Sol', 5],
#  ['Ré', 2],
#  ['Lá', 3],
#  ['Mi', 4],
#  ['Fá', 3],
#  ['Dó', 1],
#  ['Fá', 3],
#  ['Dó', 7],
#  ['Sol', 6],
#  ['Ré', 1],
#  ['Mi', 3],
#  ['Lá', 3],
#  ['Mi', 1],
#  ['Fá', 6],
#  ['Dó', 7],
#  ['Sol', 7],
#  ['Lá', 4],
#  ['Mi', 1],
#  ['Lá', 1],
#  ['Mi', 1],
#  ['Fá', 6],
#  ['Sol', 1],
#  ['Dó', 2],
#  ['Sol', 1],
#  ['Dó', 4],
#  ['Sol', 6],
#  ['Ré', 1],
#  ['Lá', 3],
#  ['Mi', 1],
#  ['Lá', 2],
#  ['Dó#', 1],
#  ['Fá', 6],
#  ['Dó', 7],
#  ['Sol', 7],
#  ['Lá', 4],
#  ['Mi', 1],
#  ['Lá', 2],
#  ['Fá', 6],
#  ['Lá#', 1],
#  ['Dó', 6],
#  ['Ré', 1],
#  ['Sol', 6],
#  ['Ré', 1],
#  ['Mi', 4],
#  ['Lá', 1],
#  ['Mi', 1],
#  ['Fá', 7],
#  ['Dó', 7],
#  ['Sol', 6],
#  ['Ré', 1],
#  ['Lá', 1],
#  ['Mi', 6],
#  ['Fá', 2],
#  ['Dó', 1],
#  ['Fá', 3],
#  ['Dó', 7],
#  ['Sol', 6],
#  ['Ré', 1],
#  ['Lá', 3],
#  ['Mi', 2],
#  ['Lá', 1],
#  ['Mi', 1],
#  ['Fá', 7],
#  ['Dó', 7],
#  ['Sol', 6],
#  ['Ré', 1],
#  ['Lá', 2],
#  ['Mi', 1],
#  ['Lá', 3],
#  ['Fá', 3],
#  ['Dó', 1],
#  ['Fá', 3],
#  ['Dó', 7],
#  ['Sol', 7],
#  ['Lá', 6],
#  ['Dó', 1],
#  ['Fá', 6],
#  ['Sol', 1],
#  ['Dó', 6],
#  ['Sol', 6],
#  ['Ré', 2],
#  ['Lá', 6],
#  ['Fá', 7],
#  ['Dó', 7],
#  ['Sol', 7],
#  ['Lá', 4],
#  ['Mi', 3],
#  ['Fá', 7],
#  ['Dó', 6],
#  ['Ré', 1],
#  ['Sol', 5],
#  ['Ré', 1],
#  ['Lá', 3],
#  ['Mi', 2],
#  ['Lá', 2],
#  ['Fá', 6],
#  ['Lá#', 1],
#  ['Dó', 7],
#  ['Sol', 2],
#  ['Ré', 1],
#  ['Sol', 2],
#  ['Ré', 2],
#  ['Lá', 2],
#  ['Mi', 2],
#  ['Lá', 2],
#  ['Mi', 1],
#  ['Fá', 2],
#  ['Dó', 1],
#  ['Fá', 3],
#  ['Dó', 7],
#  ['Ré', 1],
#  ['Sol', 6],
#  ['Lá', 2],
#  ['Mi', 1],
#  ['Lá', 4],
#  ['Fá', 7],
#  ['Dó', 7],
#  ['Sol', 6],
#  ['Ré', 1],
#  ['Lá', 2],
#  ['Mi', 2],
#  ['Lá', 1],
#  ['Mi', 2],
#  ['Fá', 2],
#  ['Dó', 1],
#  ['Fá', 3],
#  ['Dó', 7],
#  ['Sol', 2],
#  ['Ré', 1],
#  ['Sol', 1],
#  ['Ré', 2],
#  ['Sol', 1],
#  ['Lá', 2],
#  ['Mi', 1],
#  ['Lá', 3],
#  ['Mi', 1],
#  ['Fá', 2],
#  ['Dó', 2],
#  ['Fá', 3],
#  ['Dó', 3]]

# %%
notas_final
# Out:
# [['Dó', 1],
#  ['Dó#', 4],
#  ['Ré', 1],
#  ['Dó#', 1],
#  ['Sol', 1],
#  ['Dó#', 1],
#  ['Sol', 1],
#  ['Dó#', 2],
#  ['Dó', 1],
#  ['Sol', 1],
#  ['Dó#', 1],
#  ['Ré', 1],
#  ['Dó#', 1],
#  ['Sol#', 1],
#  ['Dó#', 4],
#  ['Dó', 20],
#  ['Ré', 1],
#  ['Sol', 5],
#  ['Ré', 3],
#  ['Sol', 6],
#  ['Ré', 1],
#  ['Sol', 1],
#  ['Ré', 3],
#  ['Dó', 1],
#  ['Lá', 6],
#  ['Mi', 3],
#  ['Lá', 3],
#  ['Mi', 2],
#  ['Lá', 5],
#  ['Mi', 2],
#  ['Fá', 8],
#  ['Dó', 1],
#  ['Fá', 11],
#  ['Dó', 20],
#  ['Ré', 1],
#  ['Sol', 3],
#  ['Ré', 1],
#  ['Sol', 1],
#  ['Ré', 4],
#  ['Sol', 3],
#  ['Ré', 1],
#  ['Sol', 5],
#  ['Dó', 1],
#  ['Ré', 1],
#  ['Dó#', 1],
#  ['Lá', 6],
#  ['Mi', 4],
#  ['Lá', 5],
#  ['Mi', 3],
#  ['Ré', 1],
#  ['Mi', 1],
#  ['Fá', 5],
#  ['Dó', 5],
#  ['Fá', 3],
#  ['Dó', 1],
#  ['Fá', 5],
#  ['Dó', 21],
#  ['Ré', 1],
#  ['Sol', 5],
#  ['Ré', 2],
#  ['Sol', 13],
#  ['Mi', 1],
#  ['Lá', 7],
#  ['Mi', 1],
#  ['Lá', 3],
#  ['Mi', 1],
#  ['Lá', 7],
#  ['Ré', 1],
#  ['Fá', 7],
#  ['Dó', 3],
#  ['Fá', 9],
#  ['Sol', 1],
#  ['Dó', 6],
#  ['Sol', 3],
#  ['Dó', 8],
#  ['Sol', 1],
#  ['Dó', 2],
#  ['Ré', 1],
#  ['Sol', 16],
#  ['Ré', 1],
#  ['Sol', 1],
#  ['Ré', 3],
#  ['Lá', 7],
#  ['Mi', 1],
#  ['Dó#', 1],
#  ['Lá', 2],
#  ['Mi', 2],
#  ['Lá', 4],
#  ['Mi', 1],
#  ['Lá', 1],
#  ['Mi', 1],
#  ['Fá', 17],
#  ['Dó', 1],
#  ['Fá', 2],
#  ['Ré', 1],
#  ['Dó', 5],
#  ['Sol', 1],
#  ['Dó', 1],
#  ['Sol', 1],
#  ['Ré', 1],
#  ['Dó', 3],
#  ['Dó#', 1],
#  ['Dó', 3],
#  ['Sol', 1],
#  ['Dó', 2],
#  ['Lá', 1],
#  ['Sol', 16],
#  ['Ré', 1],
#  ['Sol', 1],
#  ['Ré', 3],
#  ['Lá', 7],
#  ['Mi', 2],
#  ['Lá', 2],
#  ['Mi', 2],
#  ['Lá', 5],
#  ['Mi', 3],
#  ['Fá', 16],
#  ['Dó', 1],
#  ['Fá', 2],
#  ['Ré', 1],
#  ['Dó', 5],
#  ['Sol', 4],
#  ['Dó', 3],
#  ['Dó#', 1],
#  ['Dó', 6],
#  ['Mi', 1],
#  ['Sol', 9],
#  ['Ré', 1],
#  ['Sol', 6],
#  ['Ré', 2],
#  ['Sol', 2],
#  ['Ré', 1],
#  ['Lá', 12],
#  ['Mi', 1],
#  ['Lá', 5],
#  ['Dó', 1],
#  ['Lá', 1],
#  ['Dó', 1],
#  ['Fá', 1],
#  ['Dó', 1],
#  ['Fá', 1],
#  ['Dó', 1],
#  ['Fá', 3],
#  ['Dó', 1],
#  ['Fá', 10],
#  ['Dó#', 1],
#  ['Ré', 1],
#  ['Dó', 5],
#  ['Sol', 1],
#  ['Dó', 2],
#  ['Sol', 1],
#  ['Dó', 10],
#  ['Ré', 1],
#  ['Sol#', 1],
#  ['Sol', 4],
#  ['Ré', 3],
#  ['Sol', 10],
#  ['Ré', 2],
#  ['Si', 1],
#  ['Lá', 7],
#  ['Mi', 6],
#  ['Lá', 6],
#  ['Mi', 1],
#  ['Dó', 1],
#  ['Fá', 1],
#  ['Dó', 1],
#  ['Fá', 4],
#  ['Dó', 3],
#  ['Fá', 3],
#  ['Dó', 1],
#  ['Fá', 6],
#  ['Dó', 20],
#  ['Ré', 2],
#  ['Sol', 5],
#  ['Ré', 3],
#  ['Sol', 3],
#  ['Ré', 2],
#  ['Sol', 5],
#  ['Ré', 2],
#  ['Lá', 5],
#  ['Mi', 8],
#  ['Lá', 5],
#  ['Mi', 2],
#  ['Dó#', 1],
#  ['Fá', 8],
#  ['Dó', 1],
#  ['Fá', 11],
#  ['Dó', 5],
#  ['Sol', 3],
#  ['Lá', 1],
#  ['Dó', 10],
#  ['Lá', 1],
#  ['Ré', 2],
#  ['Sol', 4],
#  ['Ré', 4],
#  ['Sol', 2],
#  ['Ré', 1],
#  ['Sol', 5],
#  ['Ré', 3],
#  ['Lá', 8],
#  ['Mi', 3],
#  ['Lá', 8],
#  ['Mi', 2],
#  ['Fá', 6],
#  ['Dó', 4],
#  ['Fá', 10],
#  ['Dó#', 1],
#  ['Dó', 19],
#  ['Ré', 1],
#  ['Sol', 5],
#  ['Ré', 3],
#  ['Sol', 4],
#  ['Ré', 2],
#  ['Sol', 1],
#  ['Ré', 2],
#  ['Sol', 1],
#  ['Ré', 1],
#  ['Fá#', 1],
#  ['Lá', 6],
#  ['Mi', 3],
#  ['Lá', 3],
#  ['Mi', 2],
#  ['Lá', 2],
#  ['Mi', 4],
#  ['Sol', 1],
#  ['Fá', 7],
#  ['Dó', 3],
#  ['Fá', 3],
#  ['Dó', 1],
#  ['Fá', 6],
#  ['Dó', 8],
#  ['Sol', 1],
#  ['Dó#', 1],
#  ['Dó', 9],
#  ['Ré', 2],
#  ['Sol', 5],
#  ['Ré', 1],
#  ['Sol', 9],
#  ['Ré', 2],
#  ['Sol', 2],
#  ['Ré', 1],
#  ['Lá', 8],
#  ['Mi', 1],
#  ['Lá', 3],
#  ['Mi', 2],
#  ['Lá', 3],
#  ['Mi', 4],
#  ['Fá', 17],
#  ['Dó', 1],
#  ['Fá', 2],
#  ['Dó', 6],
#  ['Sol', 3],
#  ['Dó', 11],
#  ['Lá', 1],
#  ['Sol', 1],
#  ['Ré', 1],
#  ['Sol', 3],
#  ['Ré', 1],
#  ['Sol', 6],
#  ['Ré', 1],
#  ['Sol', 5],
#  ['Ré', 3],
#  ['Lá', 7],
#  ['Mi', 1],
#  ['Lá', 3],
#  ['Mi', 2],
#  ['Lá', 3],
#  ['Mi', 2],
#  ['Lá', 1],
#  ['Mi', 1],
#  ['Fá', 19],
#  ['Sol', 1],
#  ['Ré', 1],
#  ['Dó', 5],
#  ['Sol', 1],
#  ['Dó', 1],
#  ['Sol', 1],
#  ['Dó', 11],
#  ['Lá', 1],
#  ['Sol', 18],
#  ['Ré', 1],
#  ['Sol', 1],
#  ['Ré', 1],
#  ['Lá', 8],
#  ['Dó#', 1],
#  ['Lá', 2],
#  ['Mi', 2],
#  ['Lá', 2],
#  ['Mi', 1],
#  ['Lá', 3],
#  ['Mi', 1],
#  ['Fá', 6],
#  ['Dó', 3],
#  ['Fá', 8],
#  ['Dó', 1],
#  ['Fá', 3],
#  ['Dó', 5],
#  ['Sol', 2],
#  ['Dó', 5],
#  ['Dó#', 1],
#  ['Dó', 6],
#  ['Lá', 1],
#  ['Sol', 6],
#  ['Ré', 1],
#  ['Sol', 1],
#  ['Ré', 1],
#  ['Sol', 5],
#  ['Ré', 1],
#  ['Sol', 1],
#  ['Ré', 2],
#  ['Sol', 1],
#  ['Ré', 2],
#  ['Lá', 8],
#  ['Mi', 1],
#  ['Lá', 2],
#  ['Mi', 2],
#  ['Lá', 5],
#  ['Mi', 2],
#  ['Fá', 13],
#  ['Dó', 1],
#  ['Fá', 4],
#  ['Lá#', 1],
#  ['Sol#', 1],
#  ['Ré', 1],
#  ['Dó', 19],
#  ['Ré', 1],
#  ['Sol', 6],
#  ['Ré', 2],
#  ['Sol', 5],
#  ['Ré', 8],
#  ['Lá', 3],
#  ['Mi', 10],
#  ['Lá', 4],
#  ['Mi', 3],
#  ['Dó', 1],
#  ['Fá', 7],
#  ['Dó', 2],
#  ['Fá', 10],
#  ['Dó', 20],
#  ['Lá', 1],
#  ['Ré', 1],
#  ['Sol', 5],
#  ['Ré', 3],
#  ['Sol', 8],
#  ['Ré', 3],
#  ['Sol', 1],
#  ['Lá', 5],
#  ['Mi', 8],
#  ['Lá', 5],
#  ['Mi', 2],
#  ['Dó#', 1],
#  ['Fá', 8],
#  ['Dó', 1],
#  ['Fá', 11],
#  ['Dó', 19],
#  ['Ré', 2],
#  ['Sol', 10],
#  ['Ré', 1],
#  ['Sol', 8],
#  ['Ré', 1],
#  ['Lá', 2],
#  ['Mi', 12],
#  ['Lá', 2],
#  ['Mi', 4],
#  ['Fá', 8],
#  ['Dó', 3],
#  ['Fá', 10],
#  ['Dó#', 1],
#  ['Dó', 19],
#  ['Fá', 1],
#  ['Sol', 5],
#  ['Ré', 3],
#  ['Sol', 6],
#  ['Ré', 6],
#  ['Mi', 1],
#  ['Lá', 6],
#  ['Mi', 7],
#  ['Lá', 2],
#  ['Mi', 3],
#  ['Lá', 1],
#  ['Ré', 1],
#  ['Fá', 7],
#  ['Dó', 3],
#  ['Fá', 10],
#  ['Dó', 5],
#  ['Sol', 5],
#  ['Dó', 10],
#  ['Lá', 1],
#  ['Sol', 12],
#  ['Ré', 1],
#  ['Sol', 3],
#  ['Ré', 1],
#  ['Sol', 2],
#  ['Ré', 1],
#  ['Mi', 9],
#  ['Lá', 11],
#  ['Ré', 1],
#  ['Fá', 7],
#  ['Dó', 2],
#  ['Fá', 10],
#  ['Sol', 1],
#  ['Dó#', 1],
#  ['Dó', 6],
#  ['Sol', 2],
#  ['Mi', 1],
#  ['Dó', 10],
#  ['Ré', 1],
#  ['Sol', 19],
#  ['Ré', 2],
#  ['Lá', 5],
#  ['Mi', 1],
#  ['Lá', 1],
#  ['Mi', 1],
#  ['Lá', 3],
#  ['Mi', 2],
#  ['Lá', 4],
#  ['Mi', 1],
#  ['Lá', 1],
#  ['Mi', 1],
#  ['Dó', 1],
#  ['Fá', 6],
#  ['Dó', 3],
#  ['Fá', 9],
#  ['Sol', 1],
#  ['Ré', 1],
#  ['Dó', 5],
#  ['Sol', 3],
#  ['Dó', 4],
#  ['Dó#', 1],
#  ['Dó', 6],
#  ['Ré', 1],
#  ['Sol', 6],
#  ['Ré', 1],
#  ['Sol', 6],
#  ['Ré', 1],
#  ['Sol', 5],
#  ['Dó#', 1],
#  ['Ré', 1],
#  ['Lá', 5],
#  ['Mi', 1],
#  ['Lá', 2],
#  ['Ré', 1],
#  ['Lá', 2],
#  ['Mi', 2],
#  ['Lá', 5],
#  ['Si', 1],
#  ['Dó#', 1],
#  ['Fá', 9],
#  ['Dó', 1],
#  ['Fá', 9],
#  ['Sol', 1],
#  ['Ré', 1],
#  ['Dó', 5],
#  ['Sol', 3],
#  ['Dó#', 1],
#  ['Dó', 3],
#  ['Dó#', 1],
#  ['Dó', 6],
#  ['Ré', 1],
#  ['Sol', 20],
#  ['Ré', 1],
#  ['Lá', 7],
#  ['Mi', 3],
#  ['Lá', 1],
#  ['Mi', 2],
#  ['Lá', 6],
#  ['Mi', 1],
#  ['Dó', 1],
#  ['Fá', 17],
#  ['Lá#', 1],
#  ['Sol#', 1],
#  ['Ré', 1],
#  ['Dó', 12],
#  ['Dó#', 1],
#  ['Dó', 6],
#  ['Ré', 1],
#  ['Sol', 6],
#  ['Ré', 2],
#  ['Sol', 4],
#  ['Ré', 2],
#  ['Sol', 3],
#  ['Ré', 4],
#  ['Mi', 13],
#  ['Lá', 4],
#  ['Mi', 4],
#  ['Fá', 7],
#  ['Dó', 2],
#  ['Fá', 10],
#  ['Dó', 20],
#  ['Ré', 1],
#  ['Sol', 8],
#  ['Ré', 1],
#  ['Sol', 4],
#  ['Ré', 1],
#  ['Sol', 5],
#  ['Ré', 2],
#  ['Lá', 2],
#  ['Mi', 4],
#  ['Lá', 1],
#  ['Mi', 6],
#  ['Lá', 3],
#  ['Mi', 4],
#  ['Dó#', 1],
#  ['Fá', 6],
#  ['Dó', 3],
#  ['Fá', 10],
#  ['Dó', 20],
#  ['Dó#', 1],
#  ['Ré', 1],
#  ['Sol', 5],
#  ['Ré', 1],
#  ['Sol', 9],
#  ['Ré', 5],
#  ['Lá', 2],
#  ['Mi', 1],
#  ['Lá', 4],
#  ['Mi', 3],
#  ['Lá', 1],
#  ['Mi', 3],
#  ['Lá', 2],
#  ['Mi', 4],
#  ['Ré', 1],
#  ['Fá', 8],
#  ['Dó', 1],
#  ['Fá', 3],
#  ['Dó', 1],
#  ['Fá', 6],
#  ['Dó', 20],
#  ['Ré', 3],
#  ['Sol', 3],
#  ['Ré', 1],
#  ['Sol', 5],
#  ['Ré', 3],
#  ['Sol', 4],
#  ['Ré', 3],
#  ['Mi', 1],
#  ['Lá', 6],
#  ['Mi', 2],
#  ['Lá', 4],
#  ['Mi', 1],
#  ['Lá', 1],
#  ['Mi', 1],
#  ['Lá', 3],
#  ['Mi', 1],
#  ['Ré', 1],
#  ['Fá', 7],
#  ['Dó', 3],
#  ['Fá', 3],
#  ['Dó', 1],
#  ['Fá', 5],
#  ['Dó', 9],
#  ['Sol', 1],
#  ['Dó', 11],
#  ['Ré', 1],
#  ['Sol', 5],
#  ['Ré', 1],
#  ['Sol', 13],
#  ['Ré', 1],
#  ['Lá', 6],
#  ['Mi', 1],
#  ['Lá', 10],
#  ['Mi', 2],
#  ['Dó', 1],
#  ['Ré', 1],
#  ['Fá', 18],
#  ['Fá#', 1],
#  ['Sol', 1],
#  ['Dó', 18],
#  ['Sol', 2],
#  ['Ré', 1],
#  ['Sol', 12],
#  ['Ré', 1],
#  ['Sol', 2],
#  ['Ré', 2],
#  ['Sol', 2],
#  ['Ré', 1],
#  ['Lá', 17],
#  ['Mi', 3],
#  ['Sol', 1],
#  ['Fá', 18],
#  ['Fá#', 1],
#  ['Sol', 1],
#  ['Dó', 9],
#  ['Dó#', 1],
#  ['Dó', 9],
#  ['Sol', 1],
#  ['Lá', 1],
#  ['Sol', 6],
#  ['Ré', 1],
#  ['Sol', 1],
#  ['Ré', 1],
#  ['Sol', 7],
#  ['Ré', 1],
#  ['Sol', 1],
#  ['Ré', 1],
#  ['Sol', 1],
#  ['Ré', 1],
#  ['Lá', 5],
#  ['Mi', 1],
#  ['Lá', 2],
#  ['Dó#', 1],
#  ['Lá', 2],
#  ['Mi', 1],
#  ['Fá', 1],
#  ['Lá', 2],
#  ['Mi', 2],
#  ['Lá', 2],
#  ['Mi', 1],
#  ['Fá', 7],
#  ['Dó', 1],
#  ['Fá', 12],
#  ['Ré', 1],
#  ['Dó', 5],
#  ['Sol', 1],
#  ['Dó', 1],
#  ['Sol', 1],
#  ['Dó', 4],
#  ['Dó#', 1],
#  ['Dó', 6],
#  ['Ré', 2],
#  ['Sol', 5],
#  ['Ré', 1],
#  ['Sol', 10],
#  ['Ré', 3],
#  ['Sol', 1],
#  ['Lá', 7],
#  ['Mi', 2],
#  ['Lá', 2],
#  ['Mi', 2],
#  ['Lá', 5],
#  ['Mi', 2],
#  ['Fá', 18],
#  ['Lá#', 1],
#  ['Sol#', 1],
#  ['Ré', 1],
#  ['Dó', 19],
#  ['Ré', 1],
#  ['Sol', 6],
#  ['Ré', 3],
#  ['Sol', 5],
#  ['Ré', 2],
#  ['Sol', 1],
#  ['Ré', 4],
#  ['Lá', 5],
#  ['Mi', 6],
#  ['Lá', 1],
#  ['Mi', 1],
#  ['Lá', 3],
#  ['Mi', 4],
#  ['Fá', 8],
#  ['Dó', 2],
#  ['Fá', 11],
#  ['Dó', 20],
#  ['Dó#', 1],
#  ['Sol', 8],
#  ['Ré', 1],
#  ['Sol', 2],
#  ['Ré', 2],
#  ['Sol', 3],
#  ['Ré', 1],
#  ['Sol', 2],
#  ['Mi', 1],
#  ['Lá', 5],
#  ['Mi', 4],
#  ['Lá', 3],
#  ['Mi', 2],
#  ['Lá', 1],
#  ['Mi', 1],
#  ['Lá', 2],
#  ['Dó', 1],
#  ['Lá', 1],
#  ['Ré#', 1],
#  ['Fá', 7],
#  ['Dó', 2],
#  ['Fá', 10],
#  ['Ré', 1],
#  ['Dó', 2],
#  ['Sol', 2],
#  ['Dó', 1],
#  ['Sol', 2],
#  ['Dó', 9],
#  ['Sol', 1],
#  ['Dó', 2],
#  ['Dó#', 1],
#  ['Ré', 1],
#  ['Sol', 5],
#  ['Ré', 1],
#  ['Sol', 2],
#  ['Ré', 1],
#  ['Sol', 3],
#  ['Ré', 2],
#  ['Sol', 1],
#  ['Ré', 1],
#  ['Sol', 2],
#  ['Ré', 2],
#  ['Lá', 4],
#  ['Mi', 1],
#  ['Lá', 2],
#  ['Mi', 3],
#  ['Lá', 1],
#  ['Mi', 3],
#  ['Lá', 2],
#  ['Mi', 4],
#  ['Dó', 1],
#  ['Fá', 6],
#  ['Dó', 5],
#  ['Fá', 8],
#  ['Dó', 20],
#  ['Ré', 2],
#  ['Sol', 5],
#  ['Ré', 3],
#  ['Sol', 3],
#  ['Ré', 5],
#  ['Sol', 3],
#  ['Ré', 1],
#  ['Lá', 5],
#  ['Mi', 5],
#  ['Lá', 7],
#  ['Mi', 3],
#  ['Ré', 1],
#  ['Fá', 6],
#  ['Dó', 5],
#  ['Fá', 11],
#  ['Dó', 5]]
